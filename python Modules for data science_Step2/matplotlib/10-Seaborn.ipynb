# %% [markdown]
# 1. Seaborn is much better than matplotlib.
# 2. In order to visualize data from Pandas dataframe, we can only use seaborn.
# 3. It is a more advanced python library.

# %% [markdown]
# # Seaborn vs Matplotlib

# %%
import matplotlib.pyplot as plt
plt.style.use('classic')
# %matplotlib inline
import numpy as np
import pandas as pd

# %%
# Create data
rng = np.random.RandomState(0)
x = np.linspace(0,10,1000)
y = np.cumsum(rng.randn(1000,6),0)

# %%
#plot with matplotlib
plt.plot(x,y)
plt.legend('ABCDEF', ncol=2, loc='upper left')

# %%
#using Seaborn
import seaborn as sns
sns.set()     #it will simply overwrite default parameter of matplotlib

# %%
plt.plot(x,y)
plt.legend('ABCDEF',ncol=2, loc='upper left')
